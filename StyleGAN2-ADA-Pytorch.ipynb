# %% [markdown]
# # Prepare

# %%
# !pip install ninja
# !pip install ninja opensimplex

import sys

from google.colab import files
from io import BytesIO
import requests

from PIL import Image

from IPython.display import HTML
from base64 import b64encode

# !nvidia-smi -L
# Out:
# ...
# GPU 0: Tesla T4 (UUID: GPU-d7fce514-23b2-2eba-3314-da148fa69ae0)

# %%
import shutil
import os
os.chdir('/content/')
shutil.rmtree('/content/sample_data')

# %% [markdown]
# # Encoder PKL

# %% [markdown]
# # Convert to PT

# %%
# !python generate-pkl.py \
--outdir=/content/stylegan2-ada-pytorch/sample \
--trunc=0.5 \
--seeds=509-511 \
--network=/content/drive/Shareddrives/virtual/PKL-SG2-ADA/ff-met-16.pkl
# Out:
# Loading networks from "/content/drive/Shareddrives/virtual/PKL-SG2-ADA/ff-met-16.pkl"...
# Generating image for seed 509 (0/3) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 510 (1/3) ...
# Generating image for seed 511 (2/3) ...

# %%
# !python legacy.py --source /content/drive/Shareddrives/virtual/PKL/anime.pkl --dest /content/drive/Shareddrives/virtual/PKL/anime2.pkl

# %%
# !python export_weights.py /content/drive/Shareddrives/virtual/PKL-SG2-ADA/met-ff-4.pkl /content/drive/Shareddrives/virtual/PT-SG2-ADA/met-ff-4.pt

# %%
# !python generate-pt.py --size 1024 --pics 5 --ckpt /content/drive/Shareddrives/virtual/PT-SG2-ADA/met-ff-4.pt --truncation 0.2
# Out:
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# 100% 5/5 [00:03<00:00,  1.59it/s]

# %%
# !python generate-pt.py --size 1024 --pics 5 --ckpt /content/drive/Shareddrives/virtual/PT-SG2-ADA/ff-met-16.pt --truncation 0.2
# Out:
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# 100% 5/5 [00:03<00:00,  1.45it/s]

# %%
shutil.rmtree('/content/stylegan2-ada-pytorch/sample')
os.mkdir('/content/stylegan2-ada-pytorch/sample')

# %%
# !wget https://hivemind-repo.s3-us-west-2.amazonaws.com/twdne3/twdne3.pt -O /content/drive/Shareddrives/virtual/PT-SG2-ADA/anime.pt
# Out:
# --2021-04-26 18:33:37--  https://hivemind-repo.s3-us-west-2.amazonaws.com/twdne3/twdne3.pt
# Resolving hivemind-repo.s3-us-west-2.amazonaws.com (hivemind-repo.s3-us-west-2.amazonaws.com)... 52.218.232.121
# Connecting to hivemind-repo.s3-us-west-2.amazonaws.com (hivemind-repo.s3-us-west-2.amazonaws.com)|52.218.232.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 124012330 (118M) [application/x-www-form-urlencoded]
# Saving to: ‘/content/drive/Shareddrives/virtual/PT-SG2-ADA/anime.pt’
#
# /content/drive/Shar 100%[===================>] 118.27M  36.7MB/s    in 3.6s
#
# 2021-04-26 18:33:40 (33.2 MB/s) - ‘/content/drive/Shareddrives/virtual/PT-SG2-ADA/anime.pt’ saved [124012330/124012330]

# %%
# !gdown https://drive.google.com/u/0/uc?id=189RyTb_QSFsMKo33EWbnHRntp88QfjWJ -O /content/drive/Shareddrives/virtual/PKL-SG2-ADA/india.pkl
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=189RyTb_QSFsMKo33EWbnHRntp88QfjWJ
# To: /content/drive/Shareddrives/virtual/PKL-SG2-ADA/india.pkl
# 382MB [00:04, 92.6MB/s]

# %%
import os
os.chdir('/content/')
#!git clone https://github.com/bayutop/stylegan2-ada-pytorch
# !git clone https://github.com/dvschultz/stylegan2-ada-pytorch
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 258, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 258 (delta 5), reused 8 (delta 3), pack-reused 246
# Receiving objects: 100% (258/258), 1.22 MiB | 21.51 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %%
import os
os.chdir('/content/stylegan2-ada-pytorch')
#os.mkdir('/content/stylegan2-ada-pytorch/sample')

# %% [markdown]
# # Encoder PT

# %%
! pip install ninja

import sys

from google.colab import files
from io import BytesIO
import requests

from PIL import Image

from IPython.display import HTML
from base64 import b64encode
# Out:
# ...
#      |████████████████████████████████| 112kB 16.4MB/s
# ...

# %%
#!git clone https://github.com/terrybroad/deepdivelatentspace-tutorial-code
# !git clone https://github.com/twinters/deepdivelatentspace-tutorial-code
# Out:
# Cloning into 'deepdivelatentspace-tutorial-code'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 151 (delta 14), reused 23 (delta 9), pack-reused 122
# Receiving objects: 100% (151/151), 82.86 MiB | 39.74 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
import os
import shutil
#sys.path.extend(['/content/deepdivelatentspace-tutorial-code/'])
os.chdir('/content/deepdivelatentspace-tutorial-code/')
os.mkdir('/content/deepdivelatentspace-tutorial-code/aligned')
shutil.rmtree('/content/sample_data')

# %%
shutil.rmtree('/content/deepdivelatentspace-tutorial-code/projection_animation')

# %%
#Projector
    parser.add_argument("--ckpt", type=str, default='ckpt/stylegan2-ffhq.pt')
    parser.add_argument("--size", type=int, default=1024)
    parser.add_argument("--lr_rampup", type=float, default=0.05)
    parser.add_argument("--lr_rampdown", type=float, default=0.25)
    parser.add_argument("--lr", type=float, default=0.1)
    parser.add_argument("--noise", type=float, default=0.05)
    parser.add_argument("--noise_ramp", type=float, default=0.75)
    parser.add_argument("--step", type=int, default=1000)
    parser.add_argument("--noise_regularize", type=float, default=1e5)
    parser.add_argument("--mse", type=float, default=0)
    parser.add_argument("--w_plus", action="store_true")
    parser.add_argument("files", metavar="FILES", nargs="+")

# %%
# Change the input image to the relevant image you want to project
#setiap 5 step 1 images
#india 550,
#metaf 450,

# %time
! python projector.py \
--ckpt /content/drive/Shareddrives/virtual/PT-SG2-ADA/india.pt \
--noise 0.001 \
/content/deepdivelatentspace-tutorial-code/aligned/patimura-alg.png \
--step 100
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# Setting up Perceptual loss...
# Loading model from: /content/deepdivelatentspace-tutorial-code/lpips/weights/v0.1/vgg.pth
# ...[net-lin [vgg]] initialized
# ...Done
# perceptual: 0.7045; noise regularize: 0.3597; mse: 0.2464; lr: 0.0000:   1% 1/100 [00:00<00:29,  3.35it/s]/usr/local/lib/python3.7/dist-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# perceptual: 0.2592; noise regularize: 0.0000; mse: 0.1064; lr: 0.0004: 100% 100/100 [00:31<00:00,  3.13it/s]

# %%
projected_img = Image.open('/content/deepdivelatentspace-tutorial-code/projections/patimura-alg.png')
projected_img
#noise0.01
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024 at 0x7F7F30399090>

# %%
projected_img3 = Image.open('/content/deepdivelatentspace-tutorial-code/projections/patimura-alg.png')
projected_img3
#noise0.001
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024 at 0x7F7F30323D50>

# %% [markdown]
# # Encoder PT Interpolation Loop in W Space

# %%
#generate truncation    
    
    parser = argparse.ArgumentParser()
    parser.add_argument('--size', type=int, default=1024)
    parser.add_argument('--channel_multiplier', type=int, default=2)
    parser.add_argument('--ckpt', type=str, default="ckpt/stylegan2-ffhq.pt")
    parser.add_argument('--latent', type=str, default="") 
    parser.add_argument('--truncation_mean', type=int, default=4096)

# %%
! python3 generate_truncation_strip.py \
--latent /content/deepdivelatentspace-tutorial-code/projections/patimura-alg-met-450.pt \
--ckpt /content/drive/Shareddrives/virtual/PT-SG2-ADA/metfaces.pt

truncation_strip = Image.open('sample/truncation_strip.png')
truncation_strip
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
! python3 generate_truncation_strip.py \
--latent /content/deepdivelatentspace-tutorial-code/projections/patimura-alg-id-600.pt \
--ckpt /content/drive/Shareddrives/virtual/PT-SG2-ADA/india.pt

truncation_strip = Image.open('sample/truncation_strip.png')
truncation_strip
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Run script to interpolate in z space and generate individual samples
! python3 interpolation_loop_w.py --latent projections/uploaded_01.pt --truncation 1
# Sequence samples into video
